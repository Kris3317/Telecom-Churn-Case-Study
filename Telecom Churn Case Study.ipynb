# %% [markdown]
# # Problem Statement
# #### The main goal of the case study is to build ML models to predict churn.
# The model will be used for the following purposes:bservations.

# %% [markdown]
# 1. To predict whether a high-value customer will churn or not, in near future (i.e. churn phase). By knowing this, the company can take action steps such as providing special plans, discounts on recharge etc.

# %% [markdown]
# 2. To identify important variables that are strong predictors of churn. These variables may also indicate why customers choose to switch to other networks.

# %%
# Required Imports
# !pip install xgboost
# !pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\kris\appdata\roaming\python\python39\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.7.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imblearn in c:\users\kris\appdata\roaming\python\python39\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\kris\appdata\roaming\python\python39\site-packages (from imblearn) (0.12.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\kris\appdata\roaming\python\python39\site-packages (from imbalanced-learn->imblearn) (1.4.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.0.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)

# %%
# Required Imports
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_error,confusion_matrix,accuracy_score,precision_score,recall_score,precision_recall_curve,f1_score

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer

import imblearn
from imblearn.over_sampling import SMOTE

#Modules for PCA
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA


#Logistic Regression
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

# XGBoosting
from sklearn.model_selection import RandomizedSearchCV, cross_val_score, learning_curve
import xgboost as xgb

# %% [markdown]
# ### Importing the data

# %%
df = pd.read_csv('C:/Users/Kris/Upgrad/Telecom Churn Case Study/Data/train.csv')
data_dict = pd.read_csv("C:/Users/Kris/Upgrad/Telecom Churn Case Study/Data/data_dictionary.csv")
final_test_df = pd.read_csv("C:/Users/Kris/Downloads/telecom-churn-case-study-hackathon-c53/test.csv")
df.head(5)
# Out:
#    id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0   0        109             0.0             0.0             0.0
# 1   1        109             0.0             0.0             0.0
# 2   2        109             0.0             0.0             0.0
# 3   3        109             0.0             0.0             0.0
# 4   4        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8   arpu_6  \
# 0            6/30/2014            7/31/2014            8/31/2014   31.277
# 1            6/30/2014            7/31/2014            8/31/2014    0.000
# 2            6/30/2014            7/31/2014            8/31/2014   60.806
# 3            6/30/2014            7/31/2014            8/31/2014  156.362
# 4            6/30/2014            7/31/2014            8/31/2014  240.708
#
#     arpu_7  ...  sachet_3g_7  sachet_3g_8  fb_user_6  fb_user_7  fb_user_8  \
# 0   87.009  ...            0            0        NaN        NaN        NaN
# 1  122.787  ...            0            0        NaN        1.0        NaN
# 2  103.176  ...            0            0        NaN        NaN        NaN
# 3  205.260  ...            0            0        NaN        NaN        NaN
# 4  128.191  ...            1            0        1.0        1.0        1.0
#
#     aon  aug_vbc_3g  jul_vbc_3g  jun_vbc_3g  churn_probability
# 0  1958         0.0         0.0         0.0                  0
# 1   710         0.0         0.0         0.0                  0
# 2   882         0.0         0.0         0.0                  0
# 3   982         0.0         0.0         0.0                  0
# 4   647         0.0         0.0         0.0                  0
#
# [5 rows x 172 columns]

# %%
data_dict
# Out:
#        Acronyms                                        Description
# 0     CIRCLE_ID  Telecom circle area to which the customer belo...
# 1           LOC            Local calls  within same telecom circle
# 2           STD              STD calls  outside the calling circle
# 3            IC                                     Incoming calls
# 4            OG                                     Outgoing calls
# 5           T2T  Operator T to T ie within same operator mobile...
# 6       T2M                    Operator T to other operator mobile
# 7       T2O                Operator T to other operator fixed line
# 8       T2F                         Operator T to fixed lines of T
# 9       T2C                      Operator T to its own call center
# 10     ARPU                               Average revenue per user
# 11      MOU                          Minutes of usage  voice calls
# 12      AON      Age on network  number of days the customer is...
# 13     ONNET     All kind of calls within the same operator net...
# 14   OFFNET       All kind of calls outside the operator T network
# 15         ROAM  Indicates that customer is in roaming zone dur...
# 16       SPL                                         Special calls
# 17      ISD                                              ISD calls
# 18     RECH                                               Recharge
# 19      NUM                                                 Number
# 20      AMT                               Amount in local currency
# 21      MAX                                                Maximum
# 22     DATA                                        Mobile internet
# 23       3G                                              G network
# 24       AV                                                Average
# 25      VOL                     Mobile internet usage volume in MB
# 26       2G                                              G network
# 27      PCK                  Prepaid service schemes called  PACKS
# 28    NIGHT         Scheme to use during specific night hours only
# 29  MONTHLY      Service schemes with validity equivalent to a ...
# 30    SACHET     Service schemes with validity smaller than a m...
# 31      *.6                              KPI for the month of June
# 32      *.7                              KPI for the month of July
# 33      *.8                            KPI for the month of August
# 34      FB_USER  Service scheme to avail services of Facebook a...
# 35      VBC      Volume based cost  when no specific scheme is ...

# %%
for each in df.columns: print(each)
# Out:
# id
# circle_id
# loc_og_t2o_mou
# std_og_t2o_mou
# loc_ic_t2o_mou
# last_date_of_month_6
# last_date_of_month_7
# last_date_of_month_8
# arpu_6
# arpu_7
# arpu_8
# onnet_mou_6
# onnet_mou_7
# onnet_mou_8
# offnet_mou_6
# offnet_mou_7
# offnet_mou_8
# roam_ic_mou_6
# roam_ic_mou_7
# roam_ic_mou_8
# roam_og_mou_6
# roam_og_mou_7
# roam_og_mou_8
# loc_og_t2t_mou_6
# loc_og_t2t_mou_7
# loc_og_t2t_mou_8
# loc_og_t2m_mou_6
# loc_og_t2m_mou_7
# loc_og_t2m_mou_8
# loc_og_t2f_mou_6
# loc_og_t2f_mou_7
# loc_og_t2f_mou_8
# loc_og_t2c_mou_6
# loc_og_t2c_mou_7
# loc_og_t2c_mou_8
# loc_og_mou_6
# loc_og_mou_7
# loc_og_mou_8
# std_og_t2t_mou_6
# std_og_t2t_mou_7
# std_og_t2t_mou_8
# std_og_t2m_mou_6
# std_og_t2m_mou_7
# std_og_t2m_mou_8
# std_og_t2f_mou_6
# std_og_t2f_mou_7
# std_og_t2f_mou_8
# std_og_t2c_mou_6
# std_og_t2c_mou_7
# std_og_t2c_mou_8
# std_og_mou_6
# std_og_mou_7
# std_og_mou_8
# isd_og_mou_6
# isd_og_mou_7
# isd_og_mou_8
# spl_og_mou_6
# spl_og_mou_7
# spl_og_mou_8
# og_others_6
# og_others_7
# og_others_8
# total_og_mou_6
# total_og_mou_7
# total_og_mou_8
# loc_ic_t2t_mou_6
# loc_ic_t2t_mou_7
# loc_ic_t2t_mou_8
# loc_ic_t2m_mou_6
# loc_ic_t2m_mou_7
# loc_ic_t2m_mou_8
# loc_ic_t2f_mou_6
# loc_ic_t2f_mou_7
# loc_ic_t2f_mou_8
# loc_ic_mou_6
# loc_ic_mou_7
# loc_ic_mou_8
# std_ic_t2t_mou_6
# std_ic_t2t_mou_7
# std_ic_t2t_mou_8
# std_ic_t2m_mou_6
# std_ic_t2m_mou_7
# std_ic_t2m_mou_8
# std_ic_t2f_mou_6
# std_ic_t2f_mou_7
# std_ic_t2f_mou_8
# std_ic_t2o_mou_6
# std_ic_t2o_mou_7
# std_ic_t2o_mou_8
# std_ic_mou_6
# std_ic_mou_7
# std_ic_mou_8
# total_ic_mou_6
# total_ic_mou_7
# total_ic_mou_8
# spl_ic_mou_6
# spl_ic_mou_7
# spl_ic_mou_8
# isd_ic_mou_6
# isd_ic_mou_7
# isd_ic_mou_8
# ic_others_6
# ic_others_7
# ic_others_8
# total_rech_num_6
# total_rech_num_7
# total_rech_num_8
# total_rech_amt_6
# total_rech_amt_7
# total_rech_amt_8
# max_rech_amt_6
# max_rech_amt_7
# max_rech_amt_8
# date_of_last_rech_6
# date_of_last_rech_7
# date_of_last_rech_8
# last_day_rch_amt_6
# last_day_rch_amt_7
# last_day_rch_amt_8
# date_of_last_rech_data_6
# date_of_last_rech_data_7
# date_of_last_rech_data_8
# total_rech_data_6
# total_rech_data_7
# total_rech_data_8
# max_rech_data_6
# max_rech_data_7
# max_rech_data_8
# count_rech_2g_6
# count_rech_2g_7
# count_rech_2g_8
# count_rech_3g_6
# count_rech_3g_7
# count_rech_3g_8
# av_rech_amt_data_6
# av_rech_amt_data_7
# av_rech_amt_data_8
# vol_2g_mb_6
# vol_2g_mb_7
# vol_2g_mb_8
# vol_3g_mb_6
# vol_3g_mb_7
# vol_3g_mb_8
# arpu_3g_6
# arpu_3g_7
# arpu_3g_8
# arpu_2g_6
# arpu_2g_7
# arpu_2g_8
# night_pck_user_6
# night_pck_user_7
# night_pck_user_8
# monthly_2g_6
# monthly_2g_7
# monthly_2g_8
# sachet_2g_6
# sachet_2g_7
# sachet_2g_8
# monthly_3g_6
# monthly_3g_7
# monthly_3g_8
# sachet_3g_6
# sachet_3g_7
# sachet_3g_8
# fb_user_6
# fb_user_7
# fb_user_8
# aon
# aug_vbc_3g
# jul_vbc_3g
# jun_vbc_3g
# churn_probability

# %% [markdown]
# ## EDA
#
# ### Data Details

# %%
df.info(verbose=True,show_counts=True,memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69999 entries, 0 to 69998
# Data columns (total 172 columns):
#  #    Column                    Non-Null Count  Dtype
# ---   ------                    --------------  -----
#  0    id                        69999 non-null  int64
#  1    circle_id                 69999 non-null  int64
#  2    loc_og_t2o_mou            69297 non-null  float64
#  3    std_og_t2o_mou            69297 non-null  float64
#  4    loc_ic_t2o_mou            69297 non-null  float64
#  5    last_date_of_month_6      69999 non-null  object
#  6    last_date_of_month_7      69600 non-null  object
#  7    last_date_of_month_8      69266 non-null  object
#  8    arpu_6                    69999 non-null  float64
#  9    arpu_7                    69999 non-null  float64
#  10   arpu_8                    69999 non-null  float64
#  11   onnet_mou_6               67231 non-null  float64
#  12   onnet_mou_7               67312 non-null  float64
#  13   onnet_mou_8               66296 non-null  float64
#  14   offnet_mou_6              67231 non-null  float64
#  15   offnet_mou_7              67312 non-null  float64
#  16   offnet_mou_8              66296 non-null  float64
#  17   roam_ic_mou_6             67231 non-null  float64
#  18   roam_ic_mou_7             67312 non-null  float64
#  19   roam_ic_mou_8             66296 non-null  float64
#  20   roam_og_mou_6             67231 non-null  float64
#  21   roam_og_mou_7             67312 non-null  float64
#  22   roam_og_mou_8             66296 non-null  float64
#  23   loc_og_t2t_mou_6          67231 non-null  float64
#  24   loc_og_t2t_mou_7          67312 non-null  float64
#  25   loc_og_t2t_mou_8          66296 non-null  float64
#  26   loc_og_t2m_mou_6          67231 non-null  float64
#  27   loc_og_t2m_mou_7          67312 non-null  float64
#  28   loc_og_t2m_mou_8          66296 non-null  float64
#  29   loc_og_t2f_mou_6          67231 non-null  float64
#  30   loc_og_t2f_mou_7          67312 non-null  float64
#  31   loc_og_t2f_mou_8          66296 non-null  float64
#  32   loc_og_t2c_mou_6          67231 non-null  float64
#  33   loc_og_t2c_mou_7          67312 non-null  float64
#  34   loc_og_t2c_mou_8          66296 non-null  float64
#  35   loc_og_mou_6              67231 non-null  float64
#  36   loc_og_mou_7              67312 non-null  float64
#  37   loc_og_mou_8              66296 non-null  float64
#  38   std_og_t2t_mou_6          67231 non-null  float64
#  39   std_og_t2t_mou_7          67312 non-null  float64
#  40   std_og_t2t_mou_8          66296 non-null  float64
#  41   std_og_t2m_mou_6          67231 non-null  float64
#  42   std_og_t2m_mou_7          67312 non-null  float64
#  43   std_og_t2m_mou_8          66296 non-null  float64
#  44   std_og_t2f_mou_6          67231 non-null  float64
#  45   std_og_t2f_mou_7          67312 non-null  float64
#  46   std_og_t2f_mou_8          66296 non-null  float64
#  47   std_og_t2c_mou_6          67231 non-null  float64
#  48   std_og_t2c_mou_7          67312 non-null  float64
#  49   std_og_t2c_mou_8          66296 non-null  float64
#  50   std_og_mou_6              67231 non-null  float64
#  51   std_og_mou_7              67312 non-null  float64
#  52   std_og_mou_8              66296 non-null  float64
#  53   isd_og_mou_6              67231 non-null  float64
#  54   isd_og_mou_7              67312 non-null  float64
#  55   isd_og_mou_8              66296 non-null  float64
#  56   spl_og_mou_6              67231 non-null  float64
#  57   spl_og_mou_7              67312 non-null  float64
#  58   spl_og_mou_8              66296 non-null  float64
#  59   og_others_6               67231 non-null  float64
#  60   og_others_7               67312 non-null  float64
#  61   og_others_8               66296 non-null  float64
#  62   total_og_mou_6            69999 non-null  float64
#  63   total_og_mou_7            69999 non-null  float64
#  64   total_og_mou_8            69999 non-null  float64
#  65   loc_ic_t2t_mou_6          67231 non-null  float64
#  66   loc_ic_t2t_mou_7          67312 non-null  float64
#  67   loc_ic_t2t_mou_8          66296 non-null  float64
#  68   loc_ic_t2m_mou_6          67231 non-null  float64
#  69   loc_ic_t2m_mou_7          67312 non-null  float64
#  70   loc_ic_t2m_mou_8          66296 non-null  float64
#  71   loc_ic_t2f_mou_6          67231 non-null  float64
#  72   loc_ic_t2f_mou_7          67312 non-null  float64
#  73   loc_ic_t2f_mou_8          66296 non-null  float64
#  74   loc_ic_mou_6              67231 non-null  float64
#  75   loc_ic_mou_7              67312 non-null  float64
#  76   loc_ic_mou_8              66296 non-null  float64
#  77   std_ic_t2t_mou_6          67231 non-null  float64
#  78   std_ic_t2t_mou_7          67312 non-null  float64
#  79   std_ic_t2t_mou_8          66296 non-null  float64
#  80   std_ic_t2m_mou_6          67231 non-null  float64
#  81   std_ic_t2m_mou_7          67312 non-null  float64
#  82   std_ic_t2m_mou_8          66296 non-null  float64
#  83   std_ic_t2f_mou_6          67231 non-null  float64
#  84   std_ic_t2f_mou_7          67312 non-null  float64
#  85   std_ic_t2f_mou_8          66296 non-null  float64
#  86   std_ic_t2o_mou_6          67231 non-null  float64
#  87   std_ic_t2o_mou_7          67312 non-null  float64
#  88   std_ic_t2o_mou_8          66296 non-null  float64
#  89   std_ic_mou_6              67231 non-null  float64
#  90   std_ic_mou_7              67312 non-null  float64
#  91   std_ic_mou_8              66296 non-null  float64
#  92   total_ic_mou_6            69999 non-null  float64
#  93   total_ic_mou_7            69999 non-null  float64
#  94   total_ic_mou_8            69999 non-null  float64
#  95   spl_ic_mou_6              67231 non-null  float64
#  96   spl_ic_mou_7              67312 non-null  float64
#  97   spl_ic_mou_8              66296 non-null  float64
#  98   isd_ic_mou_6              67231 non-null  float64
#  99   isd_ic_mou_7              67312 non-null  float64
#  100  isd_ic_mou_8              66296 non-null  float64
#  101  ic_others_6               67231 non-null  float64
#  102  ic_others_7               67312 non-null  float64
#  103  ic_others_8               66296 non-null  float64
#  104  total_rech_num_6          69999 non-null  int64
#  105  total_rech_num_7          69999 non-null  int64
#  106  total_rech_num_8          69999 non-null  int64
#  107  total_rech_amt_6          69999 non-null  int64
#  108  total_rech_amt_7          69999 non-null  int64
#  109  total_rech_amt_8          69999 non-null  int64
#  110  max_rech_amt_6            69999 non-null  int64
#  111  max_rech_amt_7            69999 non-null  int64
#  112  max_rech_amt_8            69999 non-null  int64
#  113  date_of_last_rech_6       68898 non-null  object
#  114  date_of_last_rech_7       68765 non-null  object
#  115  date_of_last_rech_8       67538 non-null  object
#  116  last_day_rch_amt_6        69999 non-null  int64
#  117  last_day_rch_amt_7        69999 non-null  int64
#  118  last_day_rch_amt_8        69999 non-null  int64
#  119  date_of_last_rech_data_6  17568 non-null  object
#  120  date_of_last_rech_data_7  17865 non-null  object
#  121  date_of_last_rech_data_8  18417 non-null  object
#  122  total_rech_data_6         17568 non-null  float64
#  123  total_rech_data_7         17865 non-null  float64
#  124  total_rech_data_8         18417 non-null  float64
#  125  max_rech_data_6           17568 non-null  float64
#  126  max_rech_data_7           17865 non-null  float64
#  127  max_rech_data_8           18417 non-null  float64
#  128  count_rech_2g_6           17568 non-null  float64
#  129  count_rech_2g_7           17865 non-null  float64
#  130  count_rech_2g_8           18417 non-null  float64
#  131  count_rech_3g_6           17568 non-null  float64
#  132  count_rech_3g_7           17865 non-null  float64
#  133  count_rech_3g_8           18417 non-null  float64
#  134  av_rech_amt_data_6        17568 non-null  float64
#  135  av_rech_amt_data_7        17865 non-null  float64
#  136  av_rech_amt_data_8        18417 non-null  float64
#  137  vol_2g_mb_6               69999 non-null  float64
#  138  vol_2g_mb_7               69999 non-null  float64
#  139  vol_2g_mb_8               69999 non-null  float64
#  140  vol_3g_mb_6               69999 non-null  float64
#  141  vol_3g_mb_7               69999 non-null  float64
#  142  vol_3g_mb_8               69999 non-null  float64
#  143  arpu_3g_6                 17568 non-null  float64
#  144  arpu_3g_7                 17865 non-null  float64
#  145  arpu_3g_8                 18417 non-null  float64
#  146  arpu_2g_6                 17568 non-null  float64
#  147  arpu_2g_7                 17865 non-null  float64
#  148  arpu_2g_8                 18417 non-null  float64
#  149  night_pck_user_6          17568 non-null  float64
#  150  night_pck_user_7          17865 non-null  float64
#  151  night_pck_user_8          18417 non-null  float64
#  152  monthly_2g_6              69999 non-null  int64
#  153  monthly_2g_7              69999 non-null  int64
#  154  monthly_2g_8              69999 non-null  int64
#  155  sachet_2g_6               69999 non-null  int64
#  156  sachet_2g_7               69999 non-null  int64
#  157  sachet_2g_8               69999 non-null  int64
#  158  monthly_3g_6              69999 non-null  int64
#  159  monthly_3g_7              69999 non-null  int64
#  160  monthly_3g_8              69999 non-null  int64
#  161  sachet_3g_6               69999 non-null  int64
#  162  sachet_3g_7               69999 non-null  int64
#  163  sachet_3g_8               69999 non-null  int64
#  164  fb_user_6                 17568 non-null  float64
#  165  fb_user_7                 17865 non-null  float64
#  166  fb_user_8                 18417 non-null  float64
#  167  aon                       69999 non-null  int64
#  168  aug_vbc_3g                69999 non-null  float64
#  169  jul_vbc_3g                69999 non-null  float64
#  170  jun_vbc_3g                69999 non-null  float64
#  171  churn_probability         69999 non-null  int64
# dtypes: float64(135), int64(28), object(9)
# memory usage: 91.9+ MB

# %% [markdown]
# ### Handling Missing Columns

# %%
df.dropna(thresh=len(df)*0.3,axis=1,inplace = True)
print(f"Shape of Data after dropping columns that have more than 30% of missing values: {df.shape}")
# Out:
# Shape of Data after dropping columns that have more than 30% of missing values: (69999, 142)

# %%
df.describe()
# Out:
#                  id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count  69999.000000    69999.0         69297.0         69297.0
# mean   34999.000000      109.0             0.0             0.0
# std    20207.115084        0.0             0.0             0.0
# min        0.000000      109.0             0.0             0.0
# 25%    17499.500000      109.0             0.0             0.0
# 50%    34999.000000      109.0             0.0             0.0
# 75%    52498.500000      109.0             0.0             0.0
# max    69998.000000      109.0             0.0             0.0
#
#        loc_ic_t2o_mou        arpu_6        arpu_7        arpu_8   onnet_mou_6  \
# count         69297.0  69999.000000  69999.000000  69999.000000  67231.000000
# mean              0.0    283.134365    278.185912    278.858826    133.153275
# std               0.0    334.213918    344.366927    351.924315    299.963093
# min               0.0  -2258.709000  -1289.715000   -945.808000      0.000000
# 25%               0.0     93.581000     86.714000     84.095000      7.410000
# 50%               0.0    197.484000    191.588000    192.234000     34.110000
# 75%               0.0    370.791000    365.369500    369.909000    119.390000
# max               0.0  27731.088000  35145.834000  33543.624000   7376.710000
#
#         onnet_mou_7  ...  monthly_3g_7  monthly_3g_8   sachet_3g_6  \
# count  67312.000000  ...  69999.000000  69999.000000  69999.000000
# mean     133.894438  ...      0.077730      0.081958      0.075344
# std      311.277193  ...      0.383189      0.381821      0.573003
# min        0.000000  ...      0.000000      0.000000      0.000000
# 25%        6.675000  ...      0.000000      0.000000      0.000000
# 50%       32.280000  ...      0.000000      0.000000      0.000000
# 75%      115.837500  ...      0.000000      0.000000      0.000000
# max     8157.780000  ...     16.000000     16.000000     29.000000
#
#         sachet_3g_7   sachet_3g_8           aon    aug_vbc_3g    jul_vbc_3g  \
# count  69999.000000  69999.000000  69999.000000  69999.000000  69999.000000
# mean       0.081444      0.085487   1220.639709     68.108597     65.935830
# std        0.634547      0.680035    952.426321    269.328659    267.899034
# min        0.000000      0.000000    180.000000      0.000000      0.000000
# 25%        0.000000      0.000000    468.000000      0.000000      0.000000
# 50%        0.000000      0.000000    868.000000      0.000000      0.000000
# 75%        0.000000      0.000000   1813.000000      0.000000      0.000000
# max       33.000000     41.000000   4337.000000  12916.220000   9165.600000
#
#         jun_vbc_3g  churn_probability
# count  69999.00000       69999.000000
# mean      60.07674           0.101887
# std      257.22681           0.302502
# min        0.00000           0.000000
# 25%        0.00000           0.000000
# 50%        0.00000           0.000000
# 75%        0.00000           0.000000
# max    11166.21000           1.000000
#
# [8 rows x 136 columns]

# %% [markdown]
# #### Dropping variables that do not have more than 25% variance

# %%
ord_enc = OrdinalEncoder()
  
# Transform the data
df1 = ord_enc.fit_transform(df)

from sklearn.feature_selection import VarianceThreshold

var_thr = VarianceThreshold(threshold = 0.25) #Removing both constant and quasi-constant
var_thr.fit(df1)

var_thr.get_support()

concol = [column for column in df.columns 
          if column not in df.columns[var_thr.get_support()]]

for features in concol:
    if features == 'churn_probability': concol.remove(features)
    print(features)
    
df.drop(concol, axis=1, inplace=True)
# Out:
# circle_id
# loc_og_t2o_mou
# std_og_t2o_mou
# loc_ic_t2o_mou
# last_date_of_month_6
# last_date_of_month_7
# last_date_of_month_8
# std_og_t2c_mou_6
# std_og_t2c_mou_7
# std_og_t2c_mou_8
# std_ic_t2o_mou_6
# std_ic_t2o_mou_7
# std_ic_t2o_mou_8
# monthly_2g_6
# monthly_2g_7
# monthly_2g_8
# monthly_3g_6
# monthly_3g_7
# monthly_3g_8
# churn_probability

# %%
df.info(verbose=True,show_counts=True,memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69999 entries, 0 to 69998
# Data columns (total 123 columns):
#  #    Column               Non-Null Count  Dtype
# ---   ------               --------------  -----
#  0    id                   69999 non-null  int64
#  1    arpu_6               69999 non-null  float64
#  2    arpu_7               69999 non-null  float64
#  3    arpu_8               69999 non-null  float64
#  4    onnet_mou_6          67231 non-null  float64
#  5    onnet_mou_7          67312 non-null  float64
#  6    onnet_mou_8          66296 non-null  float64
#  7    offnet_mou_6         67231 non-null  float64
#  8    offnet_mou_7         67312 non-null  float64
#  9    offnet_mou_8         66296 non-null  float64
#  10   roam_ic_mou_6        67231 non-null  float64
#  11   roam_ic_mou_7        67312 non-null  float64
#  12   roam_ic_mou_8        66296 non-null  float64
#  13   roam_og_mou_6        67231 non-null  float64
#  14   roam_og_mou_7        67312 non-null  float64
#  15   roam_og_mou_8        66296 non-null  float64
#  16   loc_og_t2t_mou_6     67231 non-null  float64
#  17   loc_og_t2t_mou_7     67312 non-null  float64
#  18   loc_og_t2t_mou_8     66296 non-null  float64
#  19   loc_og_t2m_mou_6     67231 non-null  float64
#  20   loc_og_t2m_mou_7     67312 non-null  float64
#  21   loc_og_t2m_mou_8     66296 non-null  float64
#  22   loc_og_t2f_mou_6     67231 non-null  float64
#  23   loc_og_t2f_mou_7     67312 non-null  float64
#  24   loc_og_t2f_mou_8     66296 non-null  float64
#  25   loc_og_t2c_mou_6     67231 non-null  float64
#  26   loc_og_t2c_mou_7     67312 non-null  float64
#  27   loc_og_t2c_mou_8     66296 non-null  float64
#  28   loc_og_mou_6         67231 non-null  float64
#  29   loc_og_mou_7         67312 non-null  float64
#  30   loc_og_mou_8         66296 non-null  float64
#  31   std_og_t2t_mou_6     67231 non-null  float64
#  32   std_og_t2t_mou_7     67312 non-null  float64
#  33   std_og_t2t_mou_8     66296 non-null  float64
#  34   std_og_t2m_mou_6     67231 non-null  float64
#  35   std_og_t2m_mou_7     67312 non-null  float64
#  36   std_og_t2m_mou_8     66296 non-null  float64
#  37   std_og_t2f_mou_6     67231 non-null  float64
#  38   std_og_t2f_mou_7     67312 non-null  float64
#  39   std_og_t2f_mou_8     66296 non-null  float64
#  40   std_og_mou_6         67231 non-null  float64
#  41   std_og_mou_7         67312 non-null  float64
#  42   std_og_mou_8         66296 non-null  float64
#  43   isd_og_mou_6         67231 non-null  float64
#  44   isd_og_mou_7         67312 non-null  float64
#  45   isd_og_mou_8         66296 non-null  float64
#  46   spl_og_mou_6         67231 non-null  float64
#  47   spl_og_mou_7         67312 non-null  float64
#  48   spl_og_mou_8         66296 non-null  float64
#  49   og_others_6          67231 non-null  float64
#  50   og_others_7          67312 non-null  float64
#  51   og_others_8          66296 non-null  float64
#  52   total_og_mou_6       69999 non-null  float64
#  53   total_og_mou_7       69999 non-null  float64
#  54   total_og_mou_8       69999 non-null  float64
#  55   loc_ic_t2t_mou_6     67231 non-null  float64
#  56   loc_ic_t2t_mou_7     67312 non-null  float64
#  57   loc_ic_t2t_mou_8     66296 non-null  float64
#  58   loc_ic_t2m_mou_6     67231 non-null  float64
#  59   loc_ic_t2m_mou_7     67312 non-null  float64
#  60   loc_ic_t2m_mou_8     66296 non-null  float64
#  61   loc_ic_t2f_mou_6     67231 non-null  float64
#  62   loc_ic_t2f_mou_7     67312 non-null  float64
#  63   loc_ic_t2f_mou_8     66296 non-null  float64
#  64   loc_ic_mou_6         67231 non-null  float64
#  65   loc_ic_mou_7         67312 non-null  float64
#  66   loc_ic_mou_8         66296 non-null  float64
#  67   std_ic_t2t_mou_6     67231 non-null  float64
#  68   std_ic_t2t_mou_7     67312 non-null  float64
#  69   std_ic_t2t_mou_8     66296 non-null  float64
#  70   std_ic_t2m_mou_6     67231 non-null  float64
#  71   std_ic_t2m_mou_7     67312 non-null  float64
#  72   std_ic_t2m_mou_8     66296 non-null  float64
#  73   std_ic_t2f_mou_6     67231 non-null  float64
#  74   std_ic_t2f_mou_7     67312 non-null  float64
#  75   std_ic_t2f_mou_8     66296 non-null  float64
#  76   std_ic_mou_6         67231 non-null  float64
#  77   std_ic_mou_7         67312 non-null  float64
#  78   std_ic_mou_8         66296 non-null  float64
#  79   total_ic_mou_6       69999 non-null  float64
#  80   total_ic_mou_7       69999 non-null  float64
#  81   total_ic_mou_8       69999 non-null  float64
#  82   spl_ic_mou_6         67231 non-null  float64
#  83   spl_ic_mou_7         67312 non-null  float64
#  84   spl_ic_mou_8         66296 non-null  float64
#  85   isd_ic_mou_6         67231 non-null  float64
#  86   isd_ic_mou_7         67312 non-null  float64
#  87   isd_ic_mou_8         66296 non-null  float64
#  88   ic_others_6          67231 non-null  float64
#  89   ic_others_7          67312 non-null  float64
#  90   ic_others_8          66296 non-null  float64
#  91   total_rech_num_6     69999 non-null  int64
#  92   total_rech_num_7     69999 non-null  int64
#  93   total_rech_num_8     69999 non-null  int64
#  94   total_rech_amt_6     69999 non-null  int64
#  95   total_rech_amt_7     69999 non-null  int64
#  96   total_rech_amt_8     69999 non-null  int64
#  97   max_rech_amt_6       69999 non-null  int64
#  98   max_rech_amt_7       69999 non-null  int64
#  99   max_rech_amt_8       69999 non-null  int64
#  100  date_of_last_rech_6  68898 non-null  object
#  101  date_of_last_rech_7  68765 non-null  object
#  102  date_of_last_rech_8  67538 non-null  object
#  103  last_day_rch_amt_6   69999 non-null  int64
#  104  last_day_rch_amt_7   69999 non-null  int64
#  105  last_day_rch_amt_8   69999 non-null  int64
#  106  vol_2g_mb_6          69999 non-null  float64
#  107  vol_2g_mb_7          69999 non-null  float64
#  108  vol_2g_mb_8          69999 non-null  float64
#  109  vol_3g_mb_6          69999 non-null  float64
#  110  vol_3g_mb_7          69999 non-null  float64
#  111  vol_3g_mb_8          69999 non-null  float64
#  112  sachet_2g_6          69999 non-null  int64
#  113  sachet_2g_7          69999 non-null  int64
#  114  sachet_2g_8          69999 non-null  int64
#  115  sachet_3g_6          69999 non-null  int64
#  116  sachet_3g_7          69999 non-null  int64
#  117  sachet_3g_8          69999 non-null  int64
#  118  aon                  69999 non-null  int64
#  119  aug_vbc_3g           69999 non-null  float64
#  120  jul_vbc_3g           69999 non-null  float64
#  121  jun_vbc_3g           69999 non-null  float64
#  122  churn_probability    69999 non-null  int64
# dtypes: float64(99), int64(21), object(3)
# memory usage: 65.7+ MB

# %% [markdown]
# ### Isolating non numerical variables

# %%
df_non_num = df.select_dtypes(exclude = [np.number])

# %%
df_non_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69999 entries, 0 to 69998
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_of_last_rech_6  68898 non-null  object
#  1   date_of_last_rech_7  68765 non-null  object
#  2   date_of_last_rech_8  67538 non-null  object
# dtypes: object(3)
# memory usage: 1.6+ MB

# %%
for i in df_non_num:
    print(i,":",df_non_num[i].unique(),"\n")
# Out:
# date_of_last_rech_6 : ['6/22/2014' '6/12/2014' '6/11/2014' '6/15/2014' '6/25/2014' '6/30/2014'
#  '6/29/2014' '6/20/2014' '6/28/2014' '6/27/2014' '6/26/2014' '6/19/2014'
#  '6/23/2014' '6/24/2014' '6/14/2014' nan '6/5/2014' '6/8/2014' '6/6/2014'
#  '6/16/2014' '6/13/2014' '6/18/2014' '6/21/2014' '6/17/2014' '6/10/2014'
#  '6/7/2014' '6/2/2014' '6/1/2014' '6/3/2014' '6/9/2014' '6/4/2014']
#
# date_of_last_rech_7 : ['7/10/2014' '7/22/2014' '7/21/2014' '7/26/2014' '7/27/2014' '7/19/2014'
#  '7/30/2014' '7/16/2014' '7/31/2014' '7/20/2014' '7/25/2014' '7/29/2014'
#  '7/28/2014' nan '7/7/2014' '7/18/2014' '7/13/2014' '7/17/2014'
#  '7/12/2014' '7/24/2014' '7/15/2014' '7/1/2014' '7/23/2014' '7/9/2014'
#  '7/8/2014' '7/14/2014' '7/5/2014' '7/4/2014' '7/11/2014' '7/6/2014'
#  '7/2/2014' '7/3/2014']
#
# date_of_last_rech_8 : ['8/24/2014' '8/26/2014' '8/25/2014' '8/30/2014' '8/28/2014' '8/19/2014'
#  '8/5/2014' '8/27/2014' '8/16/2014' '8/21/2014' '8/22/2014' '8/23/2014'
#  nan '8/15/2014' '8/31/2014' '8/12/2014' '8/10/2014' '8/29/2014'
#  '8/20/2014' '8/13/2014' '8/18/2014' '8/11/2014' '8/14/2014' '8/6/2014'
#  '8/9/2014' '8/8/2014' '8/17/2014' '8/7/2014' '8/1/2014' '8/4/2014'
#  '8/2/2014' '8/3/2014']

# %% [markdown]
# ### Function to obtain only the day of the month rather than the entire date

# %%
def dt_fn(x):
    if x==None:
        return None
    elif isinstance(x,str):
        return int(str(x).split('/')[1])
    else:
        return None

# %%
df.date_of_last_rech_6 = (df.date_of_last_rech_6.apply(dt_fn))
df.date_of_last_rech_7= (df.date_of_last_rech_7.apply(dt_fn))
df.date_of_last_rech_8 = (df.date_of_last_rech_8.apply(dt_fn))

# %%
df[['date_of_last_rech_6', 'date_of_last_rech_7', 'date_of_last_rech_8']]
# Out:
#        date_of_last_rech_6  date_of_last_rech_7  date_of_last_rech_8
# 0                     22.0                 10.0                 24.0
# 1                     12.0                 10.0                 26.0
# 2                     11.0                 22.0                 24.0
# 3                     15.0                 21.0                 25.0
# 4                     25.0                 26.0                 30.0
# ...                    ...                  ...                  ...
# 69994                 18.0                 31.0                 31.0
# 69995                 28.0                 31.0                 27.0
# 69996                 25.0                 30.0                 29.0
# 69997                 29.0                 19.0                 26.0
# 69998                 19.0                 27.0                 25.0
#
# [69999 rows x 3 columns]

# %% [markdown]
# ### Handling missing values

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

missing_value_df = missing_value_df[missing_value_df['percent_missing'] != 0]
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#                              column_name  percent_missing
# loc_og_t2f_mou_8        loc_og_t2f_mou_8         5.290076
# loc_og_t2m_mou_8        loc_og_t2m_mou_8         5.290076
# std_og_mou_8                std_og_mou_8         5.290076
# og_others_8                  og_others_8         5.290076
# std_og_t2f_mou_8        std_og_t2f_mou_8         5.290076
# ...                                  ...              ...
# std_ic_t2t_mou_7        std_ic_t2t_mou_7         3.838626
# onnet_mou_7                  onnet_mou_7         3.838626
# date_of_last_rech_8  date_of_last_rech_8         3.515765
# date_of_last_rech_7  date_of_last_rech_7         1.762882
# date_of_last_rech_6  date_of_last_rech_6         1.572880
#
# [84 rows x 2 columns]

# %%
# df.dropna(inplace=True)

# %% [markdown]
# ### Splitting Data into Training and Test Sets

# %%
# Putting feature variable to X
X = df.drop(['churn_probability'],axis=1)

# Putting response variable to y
y = df['churn_probability']

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7,test_size=0.3,random_state=33)

# %%
print("Before Undersampling, counts of label '1': {}".format(sum(y_train == 1))) 
print("Before Undersampling, counts of label '0': {} \n".format(sum(y_train == 0)))
# Out:
# Before Undersampling, counts of label '1': 4993
# Before Undersampling, counts of label '0': 44006

# %% [markdown]
# ### Handle the imbalanceness of the data using SMOTE

# %%
imputer = KNNImputer(n_neighbors=5)
X_train_imp = imputer.fit_transform(X_train)
X_test_imp = imputer.transform(X_test)

# %%
# transform the dataset

sm = SMOTE(random_state = 33) 
X_train_smote, y_train_smote = sm.fit_resample(X_train_imp, y_train)
X_test_smote, y_test_smote = sm.fit_resample(X_test_imp, y_test)

# %%
print(f"mean of X train before using SMOTE: {np.mean(X_train_imp)}")
print(f"median of X train before using SMOTE: {np.median(X_train_imp)}")
print(f"mean of X train after using SMOTE: {np.mean(X_train_smote)}")
print(f"median of X train after using SMOTE: {np.median(X_train_smote)}")
# Out:
# mean of X train before using SMOTE: 369.1177177632265
# median of X train before using SMOTE: 1.68
# mean of X train after using SMOTE: 355.70314658607373
# median of X train after using SMOTE: 1.658563408066875

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train_trans = sc.fit_transform(X_train_smote)
X_test_trans = sc.transform(X_test_smote)

# %% [markdown]
# ### Step 4 - PCA

# %% [markdown]
# Implementing PCA to simplify high-dimensional data while preserving trends and patterns. Since this dataset has 122 variables, we can reduce the number of variables to help the model perform better

# %%
n_batches = 100 

inc_pca = IncrementalPCA()

for batch_x in np.array_split(X_train_trans, n_batches):
    inc_pca.partial_fit(batch_x)

cumsum = np.cumsum(inc_pca.explained_variance_ratio_)
d = np.argmax(cumsum >=0.95) +1

print(d) # Print the number of dimentions required to preserve 95% of variance -
# Out:
# 67

# %%
X_tmp = inc_pca.transform(X_train_trans)

# %%
# for i in range(120):
#     print(sum(inc_pca.explained_variance_ratio_[0:i])) 

print (X_tmp[:,range(d)].shape)
# Out:
# (88012, 67)

# %%
var_cumu = np.cumsum(inc_pca.explained_variance_ratio_)

# %%
fig = plt.figure(figsize=[12,8])

plt.plot(var_cumu)
plt.ylabel("Cumulative variance explained")
plt.show()

# %%
pca_comp = IncrementalPCA(n_components=d)

# %%
df_train_pca = pca_comp.fit_transform(X_train_trans)
df_train_pca.shape
# Out:
# (88012, 67)

# %%
df_test_pca = pca_comp.transform(X_test_trans)
df_test_pca.shape
# Out:
# (37722, 67)

# %% [markdown]
# ### Step 5 -  Apply Logistic Regression

# %%
grid={'C':[0.0001, 0.001, 0.1, 1, 10, 100], "penalty":["l1","l2"]}# l1 lasso l2 ridge
logreg=LogisticRegression(solver='newton-cg', max_iter=1000)
logreg_cv=GridSearchCV(logreg,grid,cv=10)
logreg_cv.fit(df_train_pca,y_train_smote)

print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
print("accuracy :",logreg_cv.best_score_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.81851355        nan 0.82792138        nan 0.82956889
#         nan 0.82945527        nan 0.82944391        nan 0.82944391]
#   warnings.warn(
# tuned hpyerparameters :(best parameters)  {'C': 0.1, 'penalty': 'l2'}
# accuracy : 0.8295688884582507

# %%
# To beat: 83.11%
# To beat: 87%

# %%
log_reg = LogisticRegression(C=0.1, penalty="l2")
log_reg_model = log_reg.fit(df_train_pca,y_train_smote)

# %%
pred_test = log_reg_model.predict_proba(df_test_pca)

# %% [markdown]
# ### Step 6 -  Model Evaluation of Logistic Regression

# %%
y_pred_df = pd.DataFrame(pred_test[:,1])
y_pred_df = y_pred_df[0].apply(lambda x : 0 if x < 0.5 else 1)
y_pred_df
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 37717    1
# 37718    1
# 37719    1
# 37720    1
# 37721    1
# Name: 0, Length: 37722, dtype: int64

# %%
log_auc = metrics.roc_auc_score(y_test_smote, y_pred_df)
log_acc = accuracy_score(y_test_smote, y_pred_df)
log_prec = precision_score(y_test_smote, y_pred_df)
log_rec = recall_score(y_test_smote, y_pred_df)
log_f1 = f1_score(y_test_smote, y_pred_df)
log_rms = mean_squared_error(y_test_smote, y_pred_df, squared=False)


print("AUC: ", log_auc)
print("Accuracy: ", log_acc)
print("Precision: ", log_prec)
print("Recall: ", log_rec)
print("F1 Score: ", log_f1)
print("RMS: ", log_rms)
# Out:
# AUC:  0.8356131700334022
# Accuracy:  0.8356131700334023
# Precision:  0.8083593141075605
# Recall:  0.8798048883940406
# F1 Score:  0.8425702607326919
# RMS:  0.40544645758299297

# %% [markdown]
# ### Step 7 -  XGBoost

# %%
xgb_cfl = xgb.XGBClassifier(objective = 'binary:logistic')

# %%
# Hyperparameter 
params = {
        'n_estimators' : [100, 200, 500, 750, 1000], 
        'learning_rate' : [0.001, 0.01, 0.1, 0.25, 0.33],  
        'min_child_weight': [7, 10, 13],
        'gamma': [0.1, 0.5, 1, 1.5],
        'subsample': [0.4, 0.6, 0.8, 1.0],
        'colsample_bytree': [0.4, 0.5, 0.6],
        'max_depth': [5, 10, 15, 20]
        }

folds = 5

param_comb = 50

random_search = RandomizedSearchCV(xgb_cfl, param_distributions=params, n_iter=param_comb, scoring='accuracy', cv=5, verbose=3, random_state=33)

# %%
random_search.fit(df_train_pca,y_train_smote)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.33, max_depth=20, min_child_weight=13, n_estimators=500, subsample=0.4;, score=0.932 total time=  15.1s
# [CV 2/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.33, max_depth=20, min_child_weight=13, n_estimators=500, subsample=0.4;, score=0.943 total time=  14.9s
# [CV 3/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.33, max_depth=20, min_child_weight=13, n_estimators=500, subsample=0.4;, score=0.942 total time=  15.9s
# [CV 4/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.33, max_depth=20, min_child_weight=13, n_estimators=500, subsample=0.4;, score=0.942 total time=  14.8s
# [CV 5/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.33, max_depth=20, min_child_weight=13, n_estimators=500, subsample=0.4;, score=0.940 total time=  14.9s
# [CV 1/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=1.0;, score=0.828 total time=  16.9s
# [CV 2/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=1.0;, score=0.848 total time=  15.8s
# [CV 3/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=1.0;, score=0.845 total time=  15.9s
# [CV 4/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=1.0;, score=0.846 total time=  14.2s
# [CV 5/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=1.0;, score=0.839 total time=  13.5s
# [CV 1/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.33, max_depth=10, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.937 total time=  10.9s
# [CV 2/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.33, max_depth=10, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.943 total time=  10.5s
# [CV 3/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.33, max_depth=10, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.943 total time=  11.0s
# [CV 4/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.33, max_depth=10, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.943 total time=  11.6s
# [CV 5/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.33, max_depth=10, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.940 total time=  12.0s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.948 total time=  27.2s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.954 total time=  28.8s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.953 total time=  28.0s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.955 total time=  25.1s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.951 total time=  22.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.872 total time=  54.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.883 total time= 1.1min
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.881 total time=  56.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.880 total time=  53.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=10, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.880 total time= 1.1min
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.940 total time=  16.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.947 total time=  14.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.944 total time=  13.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.946 total time=  13.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.946 total time=  12.9s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.6;, score=0.829 total time=  14.4s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.6;, score=0.847 total time=  14.9s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.6;, score=0.846 total time=  14.6s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.6;, score=0.846 total time=  16.1s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.6;, score=0.839 total time=  17.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.945 total time=  13.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.951 total time=  12.8s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.949 total time=  12.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.951 total time=  12.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.949 total time=  11.4s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=100, subsample=0.8;, score=0.855 total time=   5.2s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=100, subsample=0.8;, score=0.873 total time=   5.2s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=100, subsample=0.8;, score=0.869 total time=   4.8s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=100, subsample=0.8;, score=0.869 total time=   4.9s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=100, subsample=0.8;, score=0.866 total time=   5.7s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.940 total time=  11.4s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.945 total time=  11.4s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.946 total time=  11.7s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.944 total time=  19.9s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.944 total time=  14.2s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.937 total time=   9.1s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.945 total time=   9.5s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.943 total time=   9.5s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.944 total time=   9.4s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=200, subsample=1.0;, score=0.944 total time=   9.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.907 total time=   8.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.923 total time=   7.6s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.924 total time=   7.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.922 total time=   7.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.925 total time=   6.9s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.933 total time=   7.0s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.943 total time=   7.0s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.941 total time=   6.8s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.941 total time=   7.0s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.940 total time=   7.2s
# [CV 1/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.935 total time=   8.0s
# [CV 2/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.943 total time=   8.4s
# [CV 3/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.942 total time=   8.7s
# [CV 4/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.943 total time=   8.9s
# [CV 5/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=200, subsample=0.8;, score=0.941 total time=   9.4s
# [CV 1/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=500, subsample=0.6;, score=0.860 total time=  26.8s
# [CV 2/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=500, subsample=0.6;, score=0.872 total time=  27.2s
# [CV 3/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=500, subsample=0.6;, score=0.872 total time=  26.8s
# [CV 4/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=500, subsample=0.6;, score=0.872 total time=  26.8s
# [CV 5/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=10, min_child_weight=13, n_estimators=500, subsample=0.6;, score=0.869 total time=  24.6s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=13, n_estimators=1000, subsample=1.0;, score=0.933 total time= 1.2min
# [CV 2/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=13, n_estimators=1000, subsample=1.0;, score=0.940 total time= 1.1min
# [CV 3/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=13, n_estimators=1000, subsample=1.0;, score=0.938 total time= 1.1min
# [CV 4/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=13, n_estimators=1000, subsample=1.0;, score=0.938 total time= 1.1min
# [CV 5/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=15, min_child_weight=13, n_estimators=1000, subsample=1.0;, score=0.938 total time= 1.2min
# [CV 1/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.913 total time=  35.3s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.922 total time=  36.3s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.923 total time=  40.7s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.923 total time=  38.5s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.921 total time=  35.8s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.938 total time=   8.9s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.949 total time=   9.3s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.947 total time=   9.1s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.944 total time=   8.9s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=200, subsample=0.6;, score=0.944 total time=   8.6s
# [CV 1/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.891 total time= 1.0min
# [CV 2/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.902 total time= 1.2min
# [CV 3/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.899 total time= 1.0min
# [CV 4/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.900 total time= 1.1min
# [CV 5/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=7, n_estimators=500, subsample=1.0;, score=0.896 total time= 1.2min
# [CV 1/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=100, subsample=0.4;, score=0.856 total time=   7.3s
# [CV 2/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=100, subsample=0.4;, score=0.874 total time=   7.1s
# [CV 3/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=100, subsample=0.4;, score=0.870 total time=   7.3s
# [CV 4/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=100, subsample=0.4;, score=0.870 total time=   7.1s
# [CV 5/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=100, subsample=0.4;, score=0.868 total time=   6.9s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.927 total time=  10.7s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.941 total time=  10.3s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.941 total time=   9.9s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.941 total time=   9.7s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.25, max_depth=5, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.937 total time=   9.9s
# [CV 1/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.925 total time=  49.6s
# [CV 2/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.936 total time= 1.0min
# [CV 3/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.935 total time= 1.0min
# [CV 4/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.934 total time= 1.0min
# [CV 5/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=750, subsample=0.8;, score=0.933 total time=  57.9s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.4;, score=0.877 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.4;, score=0.900 total time=   1.8s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.4;, score=0.900 total time=   2.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.4;, score=0.898 total time=   2.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.4;, score=0.898 total time=   1.8s
# [CV 1/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.942 total time=  20.8s
# [CV 2/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.950 total time=  19.0s
# [CV 3/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.948 total time=  18.8s
# [CV 4/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.949 total time=  18.7s
# [CV 5/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.945 total time=  20.2s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.944 total time=  22.7s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.948 total time=  24.3s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.948 total time=  23.9s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.949 total time=  21.0s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.948 total time=  17.9s
# [CV 1/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.8;, score=0.933 total time=  10.1s
# [CV 2/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.8;, score=0.941 total time=  11.4s
# [CV 3/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.8;, score=0.940 total time=  18.8s
# [CV 4/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.8;, score=0.943 total time=  21.4s
# [CV 5/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=1000, subsample=0.8;, score=0.941 total time=  25.0s
# [CV 1/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.33, max_depth=10, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.924 total time=  12.6s
# [CV 2/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.33, max_depth=10, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.934 total time=  12.2s
# [CV 3/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.33, max_depth=10, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.935 total time=  10.6s
# [CV 4/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.33, max_depth=10, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.935 total time=  11.2s
# [CV 5/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.33, max_depth=10, min_child_weight=7, n_estimators=200, subsample=0.4;, score=0.931 total time=  10.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.916 total time= 1.6min
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.928 total time= 1.2min
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.928 total time=  47.4s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.926 total time=  43.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=15, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.926 total time=  46.1s
# [CV 1/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.4;, score=0.903 total time=   6.4s
# [CV 2/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.4;, score=0.922 total time=   6.3s
# [CV 3/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.4;, score=0.921 total time=   6.0s
# [CV 4/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.4;, score=0.921 total time=   6.0s
# [CV 5/5] END colsample_bytree=0.5, gamma=0.5, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.4;, score=0.920 total time=   5.8s
# [CV 1/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.4;, score=0.921 total time=  11.5s
# [CV 2/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.4;, score=0.938 total time=66.2min
# [CV 3/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.4;, score=0.935 total time=  11.7s
# [CV 4/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.4;, score=0.935 total time=  10.1s
# [CV 5/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=1000, subsample=0.4;, score=0.935 total time=   9.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.937 total time=   9.9s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.947 total time=  10.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.944 total time=  10.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.943 total time=  10.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=20, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.944 total time=  10.6s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.919 total time=   6.7s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.932 total time=   6.6s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.930 total time=   6.6s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.931 total time=   6.7s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.928 total time=   6.7s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.927 total time=   5.4s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.941 total time=   5.3s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.940 total time=   5.2s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.939 total time=   5.4s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.33, max_depth=5, min_child_weight=7, n_estimators=500, subsample=0.6;, score=0.937 total time=   5.3s
# [CV 1/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.1, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.933 total time=   6.6s
# [CV 2/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.1, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.942 total time=   7.5s
# [CV 3/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.1, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.939 total time=   7.5s
# [CV 4/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.1, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.941 total time=   7.7s
# [CV 5/5] END colsample_bytree=0.4, gamma=1.5, learning_rate=0.1, max_depth=10, min_child_weight=13, n_estimators=750, subsample=1.0;, score=0.939 total time=   7.9s
# [CV 1/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.944 total time=  14.1s
# [CV 2/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.951 total time=  13.6s
# [CV 3/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.949 total time=  14.2s
# [CV 4/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.949 total time=  13.6s
# [CV 5/5] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=750, subsample=1.0;, score=0.949 total time=  13.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=500, subsample=1.0;, score=0.916 total time=  37.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=500, subsample=1.0;, score=0.925 total time=  36.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=500, subsample=1.0;, score=0.924 total time=  41.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=500, subsample=1.0;, score=0.925 total time=  45.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=500, subsample=1.0;, score=0.923 total time=  39.3s
# [CV 1/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.881 total time=   9.2s
# [CV 2/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.893 total time=   9.6s
# [CV 3/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.891 total time=   9.1s
# [CV 4/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.891 total time=   9.0s
# [CV 5/5] END colsample_bytree=0.5, gamma=1.5, learning_rate=0.01, max_depth=20, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.890 total time=   9.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.827 total time=  12.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.845 total time=  12.4s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.842 total time=  12.8s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.842 total time=  13.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.001, max_depth=5, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.838 total time=  13.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.948 total time=  13.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.952 total time=  14.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.951 total time=  13.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.952 total time=  13.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=500, subsample=0.8;, score=0.950 total time=  12.6s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=0.6;, score=0.877 total time=  11.9s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=0.6;, score=0.892 total time=  11.7s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=0.6;, score=0.889 total time=  12.5s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=0.6;, score=0.892 total time=  12.7s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=0.6;, score=0.888 total time=  13.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.823 total time=   7.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.842 total time=   7.9s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.840 total time=   7.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.839 total time=   7.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.4;, score=0.836 total time=   7.2s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=1.0;, score=0.891 total time=  16.8s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=1.0;, score=0.903 total time=  16.5s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=1.0;, score=0.900 total time=  16.3s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=1.0;, score=0.902 total time=  17.6s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.5, learning_rate=0.01, max_depth=20, min_child_weight=13, n_estimators=200, subsample=1.0;, score=0.900 total time=  20.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=100, subsample=1.0;, score=0.862 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=100, subsample=1.0;, score=0.880 total time=   1.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=100, subsample=1.0;, score=0.880 total time=   1.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=100, subsample=1.0;, score=0.879 total time=   1.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=13, n_estimators=100, subsample=1.0;, score=0.880 total time=   1.7s
# [CV 1/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.895 total time= 1.6min
# [CV 2/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.905 total time= 1.7min
# [CV 3/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.902 total time= 1.6min
# [CV 4/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.903 total time= 1.8min
# [CV 5/5] END colsample_bytree=0.4, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=7, n_estimators=1000, subsample=1.0;, score=0.900 total time= 1.8min
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.826 total time=   1.8s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.843 total time=   2.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.842 total time=   1.8s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.840 total time=   1.8s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.01, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.837 total time=   1.9s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=750, subsample=0.6;, score=0.872 total time=  53.4s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=750, subsample=0.6;, score=0.884 total time=  59.6s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=750, subsample=0.6;, score=0.882 total time= 1.1min
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=750, subsample=0.6;, score=0.882 total time= 1.1min
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.001, max_depth=15, min_child_weight=10, n_estimators=750, subsample=0.6;, score=0.881 total time=  56.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=15, min_child_weight=13, n_estimators=500, subsample=0.8;, score=0.937 total time=  12.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=15, min_child_weight=13, n_estimators=500, subsample=0.8;, score=0.945 total time=  12.9s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=15, min_child_weight=13, n_estimators=500, subsample=0.8;, score=0.943 total time=  12.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=15, min_child_weight=13, n_estimators=500, subsample=0.8;, score=0.942 total time=  12.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.1, max_depth=15, min_child_weight=13, n_estimators=500, subsample=0.8;, score=0.945 total time=  11.8s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.948 total time=  23.3s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.949 total time=  22.5s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.951 total time=  24.7s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.951 total time=  27.6s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=20, min_child_weight=7, n_estimators=750, subsample=0.4;, score=0.950 total time=242.8min
# [CV 1/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=750, subsample=0.4;, score=0.826 total time=  17.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=750, subsample=0.4;, score=0.844 total time=  10.8s
# [CV 3/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=750, subsample=0.4;, score=0.843 total time=  12.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=750, subsample=0.4;, score=0.842 total time=  10.8s
# [CV 5/5] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.001, max_depth=5, min_child_weight=10, n_estimators=750, subsample=0.4;, score=0.838 total time=   9.6s
# [CV 1/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=10, n_estimators=200, subsample=0.4;, score=0.857 total time=  11.7s
# [CV 2/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=10, n_estimators=200, subsample=0.4;, score=0.874 total time=  11.9s
# [CV 3/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=10, n_estimators=200, subsample=0.4;, score=0.871 total time=  12.3s
# [CV 4/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=10, n_estimators=200, subsample=0.4;, score=0.873 total time=  12.7s
# [CV 5/5] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=20, min_child_weight=10, n_estimators=200, subsample=0.4;, score=0.869 total time=  13.3s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            random_state=None, ...),
#                    n_iter=50,
#                    param_distributions={'colsample_bytree': [0.4, 0.5, 0.6],
#                                         'gamma': [0.1, 0.5, 1, 1.5],
#                                         'learning_rate': [0.001, 0.01, 0.1,
#                                                           0.25, 0.33],
#                                         'max_depth': [5, 10, 15, 20],
#                                         'min_child_weight': [7, 10, 13],
#                                         'n_estimators': [100, 200, 500, 750,
#                                                          1000],
#                                         'subsample': [0.4, 0.6, 0.8, 1.0]},
#                    random_state=33, scoring='accuracy', verbose=3)

# %%
print('Best estimator:')
print(random_search.best_estimator_)
print('\nBest accuracy for %d-fold search with %d parameter combinations:' % (folds, param_comb))
print(random_search.best_score_ )
print('\nBest hyperparameters:')
print(random_search.best_params_)
# Out:
# Best estimator:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.4, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.1, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=10, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
#
# Best accuracy for 5-fold search with 50 parameter combinations:
# 0.9521201959905465
#
# Best hyperparameters:
# {'subsample': 0.8, 'n_estimators': 1000, 'min_child_weight': 10, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0.1, 'colsample_bytree': 0.4}

# %% [markdown]
# ### XGBoost Model Evalutaion

# %%
xgb_predictions_hpt = random_search.predict(df_test_pca)

xgb_auc = metrics.roc_auc_score(y_test_smote, xgb_predictions_hpt)
xgb_acc = accuracy_score(y_test_smote, xgb_predictions_hpt)
xgb_prec = precision_score(y_test_smote, xgb_predictions_hpt)
xgb_rec = recall_score(y_test_smote, xgb_predictions_hpt)
xgb_f1 = f1_score(y_test_smote, xgb_predictions_hpt)
xgb_rms = mean_squared_error(y_test_smote, xgb_predictions_hpt, squared=False)

print("AUC: ", xgb_auc)
print("Accuracy: ", xgb_acc)
print("Precision: ", xgb_prec)
print("Recall: ", xgb_rec)
print("F1 score: ", xgb_f1)
print("RMS: ", xgb_rms)
# Out:
# AUC:  0.8556280154816819
# Accuracy:  0.8556280154816818
# Precision:  0.9226794378977882
# Recall:  0.7763109061025396
# F1 score:  0.8431903253671177
# RMS:  0.3799631357359793

# %% [markdown]
# ### Model Comparison

# %%
t_dict = {'Measures': ['AUC', 'Accuracy', 'Precision', 'Recall', 'F1 score', 'RMS'], 'Logistic Regression': [log_auc, log_acc, log_prec, log_rec, log_f1, log_rms], 'XGBoost': [xgb_auc, xgb_acc, xgb_prec, xgb_rec, xgb_f1, xgb_rms]} 
pd.DataFrame(t_dict)
# Out:
#     Measures  Logistic Regression   XGBoost
# 0        AUC             0.835613  0.855628
# 1   Accuracy             0.835613  0.855628
# 2  Precision             0.808359  0.922679
# 3     Recall             0.879805  0.776311
# 4   F1 score             0.842570  0.843190
# 5        RMS             0.405446  0.379963

# %% [markdown]
# ### Problem Statement:
#
# Since the primary concern is to ensure that positives (e.g., identifying customers who will churn) are correctly classified, rather than focusing on minimizing false negatives, then precision becomes the most important metric.
#
# Precision measures the proportion of true positive predictions out of all positive predictions made by the model. In other words, it evaluates the model's ability to avoid false positives. A higher precision indicates fewer false positives, meaning that the model is better at correctly identifying customers who will churn without mistakenly classifying too many non-churners as churners.
#
# Therefore, in this scenario, where the emphasis is on getting the positives right, the model with the highest precision would be considered the best choice and therefore we can proceed with the XGBoost model with the hyperparameters seen above.

# %% [markdown]
# ### Step 9 -  Drawing Inferences

# %%
# Find important features index

df_feature = pd.DataFrame(random_search.best_estimator_.feature_importances_)
df_feature.columns = ['feature_importance']
df_feature.nlargest(6,'feature_importance')
# Out:
#     feature_importance
# 1             0.068373
# 6             0.063997
# 0             0.043146
# 5             0.030017
# 27            0.027649
# 15            0.024928

# %%
# Find important features name

pos = [1,6,5,27,15]
colname = X.columns[pos]
colname
# Out:
# Index(['arpu_6', 'onnet_mou_8', 'onnet_mou_7', 'loc_og_t2c_mou_8',
#        'roam_og_mou_8'],
#       dtype='object')

# %% [markdown]
# #### The most important features that can help with identifiying churn are:
# 1. Average Revenue per user
# 2. All kind of calls within the same operator network in minutes of usage in the latest month
# 3. All kind of calls within the same operator network in minutes of usage in the month previous to the latest month
# 4. Local outgoing calls  within same telecom circle to the operator in minutes of usage
# 5. Indicates that customer is in roaming zone during the outgoing call in minutes of usage
